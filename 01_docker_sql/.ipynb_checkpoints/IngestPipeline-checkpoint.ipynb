# %%
# !pip install psycopg2
# !pip install tqdm

# %%
import pandas as pd
import numpy as np
from sqlalchemy import engine, create_engine
from tqdm import tqdm
import time

# %%
prefix = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/green/'
url = f'{prefix}green_tripdata_2019-10.csv.gz'

df = pd.read_csv(
    url
)
# Out:
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_17700\2564447663.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %%
df
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0            2.0  2019-10-01 00:26:02   2019-10-01 00:39:58
# 1            1.0  2019-10-01 00:18:11   2019-10-01 00:22:38
# 2            1.0  2019-10-01 00:09:31   2019-10-01 00:24:47
# 3            1.0  2019-10-01 00:37:40   2019-10-01 00:41:49
# 4            2.0  2019-10-01 00:08:13   2019-10-01 00:17:56
# ...          ...                  ...                   ...
# 476381       NaN  2019-10-31 23:30:00   2019-11-01 00:00:00
# 476382       NaN  2019-10-31 23:03:00   2019-10-31 23:24:00
# 476383       NaN  2019-10-31 23:02:00   2019-10-31 23:23:00
# 476384       NaN  2019-10-31 23:42:00   2019-10-31 23:56:00
# 476385       NaN  2019-10-31 23:23:00   2019-10-31 23:56:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N         1.0           112           196
# 1                       N         1.0            43           263
# ...

# %%
len(df)
# Out:
# 476386

# %%
dtypes = {
    'VendorID': 'Int64',
    'store_and_fwd_flag': 'object',
    'RatecodeID': 'Int64',
    'PULocationID': 'Int64',
    'DOLocationID': 'Int64',
    'passenger_count': 'Int64',
    'trip_distance': 'float64',
    'fare_amount': 'float64',
    'extra': 'float64',
    'mta_tax': 'float64',
    'tip_amount': 'float64',
    'tolls_amount': 'float64',
    'ehail_fee': 'float64',
    'improvement_surcharge': 'float64',
    'total_amount': 'float64',
    'payment_type': 'Int64',
    'trip_type': 'Int64',
    'congestion_surcharge': 'float64'
}

dates = [
    'lpep_pickup_datetime', 
    'lpep_dropoff_datetime'
]

# %%
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5433/ny_taxi')

# %%
print(pd.io.sql.get_schema(frame= df, 
                           name= 'ny_green_taxi')
     )
# Out:
# CREATE TABLE "ny_green_taxi" (
# "VendorID" REAL,
#   "lpep_pickup_datetime" TEXT,
#   "lpep_dropoff_datetime" TEXT,
#   "store_and_fwd_flag" TEXT,
#   "RatecodeID" REAL,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "ehail_fee" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "payment_type" REAL,
#   "trip_type" REAL,
#   "congestion_surcharge" REAL
# )

# %%
df = pd.read_csv(
    url, 
    dtype = dtypes, 
    parse_dates = dates,
    iterator = True,
    chunksize = 50000
)

# %%
table_name = 'ny_green_taxi'

for chunk_no, df_part in enumerate(df, start=1):
    df_part.head(0).to_sql(name= table_name, 
                   con= engine,
                   if_exists = 'replace'
                  )
    print(f'{len(df_part)} Rows were added to the {table_name} table; Dataframe No. {chunk_no}')
# Out:
# 50000 Rows were added to the ny_green_taxi table; Dataframe No. 1
# 50000 Rows were added to the ny_green_taxi table; Dataframe No. 2
# 50000 Rows were added to the ny_green_taxi table; Dataframe No. 3
# 50000 Rows were added to the ny_green_taxi table; Dataframe No. 4
# 50000 Rows were added to the ny_green_taxi table; Dataframe No. 5
# 50000 Rows were added to the ny_green_taxi table; Dataframe No. 6
# 50000 Rows were added to the ny_green_taxi table; Dataframe No. 7
# 50000 Rows were added to the ny_green_taxi table; Dataframe No. 8
# 50000 Rows were added to the ny_green_taxi table; Dataframe No. 9
# 26386 Rows were added to the ny_green_taxi table; Dataframe No. 10
